# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 605

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Set base url that accesses my api key and jsonify it
BaseUrl = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key + "&q=" + 'Atlanta'
requests.get(BaseUrl).json()
# Out:
# {'coord': {'lon': -84.388, 'lat': 33.749},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 74.1,
#   'feels_like': 75.43,
#   'temp_min': 72.39,
#   'temp_max': 76.75,
#   'pressure': 1020,
#   'humidity': 90},
#  'visibility': 10000,
#  'wind': {'speed': 3.44, 'deg': 140},
#  'clouds': {'all': 0},
#  'dt': 1659229260,
#  'sys': {'type': 2,
#   'id': 2006620,
#   'country': 'US',
#   'sunrise': 1659178079,
#   'sunset': 1659227987},
#  'timezone': -14400,
#  'id': 4180439,
#  'name': 'Atlanta',
#  'cod': 200}

# %%
# # Establish variables to pull city data in sets of 50 and sleeping between to give the api a break.
# print("Beginning Data Retrieval\n")
# CityNumber = 1
# CityNumberRound = 1

# #Create a bunch of empty lists to fill data into to eventually build a DF with.
# citys = []
# lats = []
# longs = []
# temperatures = []
# humiditylevels = []
# cloudiness = []
# windspeed = []
# countries = []
# dates = []

# # For loop that loops through each city from the 605 length list above and appends all the weather attributes to the
# # empty lists. Try / except loop controls for cities not being found in the open weather map api. 
# for city in cities:
#     print(f'Processing record {CityNumber} of Set {CityNumberRound} | {city}')
#     try:
#         CityUrl = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key + "&q=" + city
#         CityWeather = requests.get(CityUrl).json()
#         citys.append(CityWeather["name"])
#         lats.append(CityWeather["coord"]["lat"])
#         longs.append(CityWeather["coord"]["lon"])
#         temperatures.append(CityWeather["main"]["temp_max"])
#         humiditylevels.append(CityWeather["main"]["humidity"])
#         cloudiness.append(CityWeather["clouds"]["all"])
#         windspeed.append(CityWeather["wind"]["speed"])
#         countries.append(CityWeather["sys"]["country"])
#         dates.append(CityWeather["dt"])
#         CityNumber = CityNumber + 1
#         if CityNumber > 50:
#             CityNumber = 1
#             CityNumberRound = CityNumberRound + 1
#             time.sleep(50)
#     except:
#         print("City not found, skipping.")
# Out:
# Beginning Data Retrieval
#
# Processing record 1 of Set 1 | pervomayskaya
# Processing record 2 of Set 1 | busselton
# Processing record 3 of Set 1 | lugovoy
# Processing record 4 of Set 1 | provideniya
# Processing record 5 of Set 1 | kodiak
# Processing record 6 of Set 1 | pangkalanbuun
# Processing record 7 of Set 1 | chum phae
# Processing record 8 of Set 1 | belushya guba
# City not found, skipping.
# Processing record 8 of Set 1 | pauini
# Processing record 9 of Set 1 | atuona
# Processing record 10 of Set 1 | byron bay
# Processing record 11 of Set 1 | birobidzhan
# Processing record 12 of Set 1 | kagadi
# Processing record 13 of Set 1 | lazaro cardenas
# Processing record 14 of Set 1 | taolanaro
# City not found, skipping.
# Processing record 14 of Set 1 | bluff
# Processing record 15 of Set 1 | albany
# Processing record 16 of Set 1 | alindao
# Processing record 17 of Set 1 | nome
# Processing record 18 of Set 1 | nizhneyansk
# City not found, skipping.
# Processing record 18 of Set 1 | poum
# Processing record 19 of Set 1 | baruun-urt
# Processing record 20 of Set 1 | bambous virieux
# Processing record 21 of Set 1 | puerto ayora
# Processing record 22 of Set 1 | rikitea
# Processing record 23 of Set 1 | coahuayana
# Processing record 24 of Set 1 | payo
# Processing record 25 of Set 1 | castro
# Processing record 26 of Set 1 | kirakira
# Processing record 27 of Set 1 | kaputa
# Processing record 28 of Set 1 | vidim
# Processing record 29 of Set 1 | mar del plata
# Processing record 30 of Set 1 | surt
# Processing record 31 of Set 1 | mataura
# Processing record 32 of Set 1 | port macquarie
# Processing record 33 of Set 1 | laishevo
# Processing record 34 of Set 1 | qaanaaq
# Processing record 35 of Set 1 | grindavik
# Processing record 36 of Set 1 | tautira
# Processing record 37 of Set 1 | faanui
# Processing record 38 of Set 1 | umea
# Processing record 39 of Set 1 | hermanus
# Processing record 40 of Set 1 | ushuaia
# Processing record 41 of Set 1 | kapaa
# Processing record 42 of Set 1 | victoria
# Processing record 43 of Set 1 | newcastle
# Processing record 44 of Set 1 | itarema
# Processing record 45 of Set 1 | puerto madryn
# Processing record 46 of Set 1 | hobart
# Processing record 47 of Set 1 | roma
# Processing record 48 of Set 1 | east london
# Processing record 49 of Set 1 | rock sound
# Processing record 50 of Set 1 | chokurdakh
# Processing record 1 of Set 2 | butaritari
# Processing record 2 of Set 2 | lebu
# Processing record 3 of Set 2 | jamestown
# Processing record 4 of Set 2 | anadyr
# Processing record 5 of Set 2 | ranong
# Processing record 6 of Set 2 | sao filipe
# Processing record 7 of Set 2 | kruisfontein
# Processing record 8 of Set 2 | yeppoon
# Processing record 9 of Set 2 | sola
# Processing record 10 of Set 2 | kenai
# Processing record 11 of Set 2 | mahebourg
# Processing record 12 of Set 2 | bubaque
# Processing record 13 of Set 2 | igrim
# Processing record 14 of Set 2 | punta arenas
# Processing record 15 of Set 2 | lata
# Processing record 16 of Set 2 | nikolskoye
# Processing record 17 of Set 2 | san patricio
# Processing record 18 of Set 2 | thompson
# Processing record 19 of Set 2 | bathsheba
# Processing record 20 of Set 2 | tuktoyaktuk
# Processing record 21 of Set 2 | saskylakh
# Processing record 22 of Set 2 | illoqqortoormiut
# City not found, skipping.
# Processing record 22 of Set 2 | haines junction
# Processing record 23 of Set 2 | black river
# Processing record 24 of Set 2 | den helder
# Processing record 25 of Set 2 | kaya
# Processing record 26 of Set 2 | yellowknife
# Processing record 27 of Set 2 | torbay
# Processing record 28 of Set 2 | dikson
# Processing record 29 of Set 2 | imbituba
# Processing record 30 of Set 2 | hithadhoo
# Processing record 31 of Set 2 | grand centre
# City not found, skipping.
# Processing record 31 of Set 2 | moose factory
# Processing record 32 of Set 2 | college
# Processing record 33 of Set 2 | ikryanoye
# Processing record 34 of Set 2 | fortuna
# Processing record 35 of Set 2 | luan
# Processing record 36 of Set 2 | takoradi
# Processing record 37 of Set 2 | labuhan
# Processing record 38 of Set 2 | leningradskiy
# Processing record 39 of Set 2 | marsh harbour
# Processing record 40 of Set 2 | viedma
# Processing record 41 of Set 2 | andevoranto
# City not found, skipping.
# Processing record 41 of Set 2 | zhigalovo
# Processing record 42 of Set 2 | lompoc
# Processing record 43 of Set 2 | amderma
# City not found, skipping.
# Processing record 43 of Set 2 | hilo
# Processing record 44 of Set 2 | dharmanagar
# Processing record 45 of Set 2 | mizan teferi
# Processing record 46 of Set 2 | luderitz
# Processing record 47 of Set 2 | olafsvik
# Processing record 48 of Set 2 | ketchikan
# Processing record 49 of Set 2 | roald
# Processing record 50 of Set 2 | bengkulu
# Processing record 1 of Set 3 | guhagar
# Processing record 2 of Set 3 | sinnamary
# Processing record 3 of Set 3 | udachnyy
# Processing record 4 of Set 3 | tandil
# Processing record 5 of Set 3 | cap-aux-meules
# Processing record 6 of Set 3 | attawapiskat
# City not found, skipping.
# Processing record 6 of Set 3 | saint george
# Processing record 7 of Set 3 | dingle
# Processing record 8 of Set 3 | pisco
# Processing record 9 of Set 3 | cape town
# Processing record 10 of Set 3 | saldanha
# Processing record 11 of Set 3 | ondjiva
# Processing record 12 of Set 3 | tessalit
# Processing record 13 of Set 3 | georgetown
# Processing record 14 of Set 3 | tsihombe
# City not found, skipping.
# Processing record 14 of Set 3 | barentsburg
# City not found, skipping.
# Processing record 14 of Set 3 | bonthe
# Processing record 15 of Set 3 | portobelo
# Processing record 16 of Set 3 | praia da vitoria
# Processing record 17 of Set 3 | khatanga
# Processing record 18 of Set 3 | mogadishu
# Processing record 19 of Set 3 | saint anthony
# Processing record 20 of Set 3 | esperance
# Processing record 21 of Set 3 | labutta
# City not found, skipping.
# Processing record 21 of Set 3 | flin flon
# Processing record 22 of Set 3 | mareeba
# Processing record 23 of Set 3 | tigil
# Processing record 24 of Set 3 | venkatagiri
# Processing record 25 of Set 3 | namibe
# Processing record 26 of Set 3 | longyearbyen
# Processing record 27 of Set 3 | port alfred
# Processing record 28 of Set 3 | ancud
# Processing record 29 of Set 3 | port lincoln
# Processing record 30 of Set 3 | boa vista
# Processing record 31 of Set 3 | bossembele
# City not found, skipping.
# Processing record 31 of Set 3 | samfya
# Processing record 32 of Set 3 | sentyabrskiy
# City not found, skipping.
# Processing record 32 of Set 3 | tasiilaq
# Processing record 33 of Set 3 | saint-philippe
# Processing record 34 of Set 3 | tuatapere
# Processing record 35 of Set 3 | tucuman
# Processing record 36 of Set 3 | kawalu
# Processing record 37 of Set 3 | doctor pedro p. pena
# City not found, skipping.
# Processing record 37 of Set 3 | bandarbeyla
# Processing record 38 of Set 3 | beisfjord
# Processing record 39 of Set 3 | upernavik
# Processing record 40 of Set 3 | aykhal
# Processing record 41 of Set 3 | barrow
# Processing record 42 of Set 3 | bowen
# Processing record 43 of Set 3 | samusu
# City not found, skipping.
# Processing record 43 of Set 3 | fomboni
# Processing record 44 of Set 3 | motygino
# Processing record 45 of Set 3 | bonavista
# Processing record 46 of Set 3 | ribeira grande
# Processing record 47 of Set 3 | naze
# Processing record 48 of Set 3 | asau
# Processing record 49 of Set 3 | vaini
# Processing record 50 of Set 3 | kavieng
# Processing record 1 of Set 4 | egvekinot
# Processing record 2 of Set 4 | port elizabeth
# Processing record 3 of Set 4 | carnarvon
# Processing record 4 of Set 4 | muros
# Processing record 5 of Set 4 | vao
# Processing record 6 of Set 4 | sinkat
# City not found, skipping.
# Processing record 6 of Set 4 | roberval
# Processing record 7 of Set 4 | bethel
# Processing record 8 of Set 4 | arraial do cabo
# Processing record 9 of Set 4 | severo-kurilsk
# Processing record 10 of Set 4 | hobyo
# Processing record 11 of Set 4 | diebougou
# Processing record 12 of Set 4 | goderich
# Processing record 13 of Set 4 | galle
# Processing record 14 of Set 4 | north bend
# Processing record 15 of Set 4 | windsor
# Processing record 16 of Set 4 | padilla
# Processing record 17 of Set 4 | belen
# Processing record 18 of Set 4 | kokkola
# Processing record 19 of Set 4 | hasaki
# Processing record 20 of Set 4 | huilong
# Processing record 21 of Set 4 | talnakh
# Processing record 22 of Set 4 | barguzin
# Processing record 23 of Set 4 | puerto penasco
# Processing record 24 of Set 4 | mwene-ditu
# Processing record 25 of Set 4 | guarapari
# Processing record 26 of Set 4 | solnechnyy
# Processing record 27 of Set 4 | tibu
# Processing record 28 of Set 4 | kibaya
# Processing record 29 of Set 4 | port blair
# Processing record 30 of Set 4 | bosaso
# Processing record 31 of Set 4 | port moresby
# Processing record 32 of Set 4 | lamu
# Processing record 33 of Set 4 | grand gaube
# Processing record 34 of Set 4 | poplar bluff
# Processing record 35 of Set 4 | vanimo
# Processing record 36 of Set 4 | avarua
# Processing record 37 of Set 4 | aranos
# Processing record 38 of Set 4 | nakhon si thammarat
# Processing record 39 of Set 4 | araguacu
# Processing record 40 of Set 4 | new norfolk
# Processing record 41 of Set 4 | homer
# Processing record 42 of Set 4 | helmsdale
# Processing record 43 of Set 4 | coihaique
# Processing record 44 of Set 4 | batie
# Processing record 45 of Set 4 | norman wells
# Processing record 46 of Set 4 | bredasdorp
# Processing record 47 of Set 4 | mount gambier
# Processing record 48 of Set 4 | broken hill
# Processing record 49 of Set 4 | gamba
# Processing record 50 of Set 4 | arandis
# Processing record 1 of Set 5 | larsnes
# Processing record 2 of Set 5 | hirara
# Processing record 3 of Set 5 | lagoa
# Processing record 4 of Set 5 | mekhelta
# City not found, skipping.
# Processing record 4 of Set 5 | michigan city
# Processing record 5 of Set 5 | westport
# Processing record 6 of Set 5 | paris
# Processing record 7 of Set 5 | korla
# Processing record 8 of Set 5 | umzimvubu
# City not found, skipping.
# Processing record 8 of Set 5 | morondava
# Processing record 9 of Set 5 | ternate
# Processing record 10 of Set 5 | tumannyy
# City not found, skipping.
# Processing record 10 of Set 5 | nambucca heads
# Processing record 11 of Set 5 | hazorasp
# Processing record 12 of Set 5 | pahrump
# Processing record 13 of Set 5 | ilhabela
# Processing record 14 of Set 5 | kaitangata
# Processing record 15 of Set 5 | rocha
# Processing record 16 of Set 5 | kamaishi
# Processing record 17 of Set 5 | rawannawi
# City not found, skipping.
# Processing record 17 of Set 5 | sergeyevka
# Processing record 18 of Set 5 | tecoanapa
# Processing record 19 of Set 5 | mys shmidta
# City not found, skipping.
# Processing record 19 of Set 5 | pachino
# Processing record 20 of Set 5 | souillac
# Processing record 21 of Set 5 | viljoenskroon
# Processing record 22 of Set 5 | sebina
# Processing record 23 of Set 5 | chivay
# Processing record 24 of Set 5 | sur
# Processing record 25 of Set 5 | grants pass
# Processing record 26 of Set 5 | matara
# Processing record 27 of Set 5 | leku
# Processing record 28 of Set 5 | tawkar
# City not found, skipping.
# Processing record 28 of Set 5 | pattani
# Processing record 29 of Set 5 | ures
# Processing record 30 of Set 5 | gurskoye
# City not found, skipping.
# Processing record 30 of Set 5 | tabou
# Processing record 31 of Set 5 | xuanhua
# Processing record 32 of Set 5 | alofi
# Processing record 33 of Set 5 | candolim
# Processing record 34 of Set 5 | airai
# Processing record 35 of Set 5 | saleaula
# City not found, skipping.
# Processing record 35 of Set 5 | hambantota
# Processing record 36 of Set 5 | lavrentiya
# Processing record 37 of Set 5 | gorontalo
# Processing record 38 of Set 5 | codrington
# Processing record 39 of Set 5 | ilulissat
# Processing record 40 of Set 5 | san cristobal
# Processing record 41 of Set 5 | santiago del estero
# Processing record 42 of Set 5 | kedrovyy
# Processing record 43 of Set 5 | aksarka
# Processing record 44 of Set 5 | cherskiy
# Processing record 45 of Set 5 | visnes
# Processing record 46 of Set 5 | mrirt
# City not found, skipping.
# Processing record 46 of Set 5 | zambezi
# Processing record 47 of Set 5 | wahran
# City not found, skipping.
# Processing record 47 of Set 5 | vrangel
# Processing record 48 of Set 5 | san francisco
# Processing record 49 of Set 5 | trelew
# Processing record 50 of Set 5 | hastings
# Processing record 1 of Set 6 | jinchang
# Processing record 2 of Set 6 | kaeo
# Processing record 3 of Set 6 | valparaiso
# Processing record 4 of Set 6 | pevek
# Processing record 5 of Set 6 | okhotsk
# Processing record 6 of Set 6 | wembley
# Processing record 7 of Set 6 | palu
# Processing record 8 of Set 6 | bilma
# Processing record 9 of Set 6 | vangaindrano
# Processing record 10 of Set 6 | carbonia
# Processing record 11 of Set 6 | bairiki
# Processing record 12 of Set 6 | ajdabiya
# Processing record 13 of Set 6 | kazalinsk
# City not found, skipping.
# Processing record 13 of Set 6 | rungata
# City not found, skipping.
# Processing record 13 of Set 6 | havelock
# Processing record 14 of Set 6 | madang
# Processing record 15 of Set 6 | tiksi
# Processing record 16 of Set 6 | jumla
# Processing record 17 of Set 6 | vila franca do campo
# Processing record 18 of Set 6 | flinders
# Processing record 19 of Set 6 | erzin
# Processing record 20 of Set 6 | margate
# Processing record 21 of Set 6 | rupert
# Processing record 22 of Set 6 | marshfield
# Processing record 23 of Set 6 | maumere
# Processing record 24 of Set 6 | ayan
# Processing record 25 of Set 6 | mbanza-ngungu
# Processing record 26 of Set 6 | osakarovka
# Processing record 27 of Set 6 | nguiu
# City not found, skipping.
# Processing record 27 of Set 6 | villazon
# Processing record 28 of Set 6 | cody
# Processing record 29 of Set 6 | takob
# City not found, skipping.
# Processing record 29 of Set 6 | kapit
# Processing record 30 of Set 6 | sorong
# Processing record 31 of Set 6 | rio gallegos
# Processing record 32 of Set 6 | dunedin
# Processing record 33 of Set 6 | tual
# Processing record 34 of Set 6 | lynn haven
# Processing record 35 of Set 6 | muravlenko
# Processing record 36 of Set 6 | sechura
# Processing record 37 of Set 6 | karkaralinsk
# City not found, skipping.
# Processing record 37 of Set 6 | barawe
# City not found, skipping.
# Processing record 37 of Set 6 | rawson
# Processing record 38 of Set 6 | aklavik
# Processing record 39 of Set 6 | alanya
# Processing record 40 of Set 6 | chone
# Processing record 41 of Set 6 | ukmerge
# Processing record 42 of Set 6 | marcona
# City not found, skipping.
# Processing record 42 of Set 6 | urfa
# City not found, skipping.
# Processing record 42 of Set 6 | cabo san lucas
# Processing record 43 of Set 6 | umm durman
# City not found, skipping.
# Processing record 43 of Set 6 | araouane
# Processing record 44 of Set 6 | mingaora
# Processing record 45 of Set 6 | brezice
# Processing record 46 of Set 6 | grand river south east
# City not found, skipping.
# Processing record 46 of Set 6 | srednekolymsk
# Processing record 47 of Set 6 | birjand
# Processing record 48 of Set 6 | abyek
# Processing record 49 of Set 6 | palabuhanratu
# City not found, skipping.
# Processing record 49 of Set 6 | brandon
# Processing record 50 of Set 6 | prabumulih
# Processing record 1 of Set 7 | teshie
# Processing record 2 of Set 7 | sao felix do xingu
# Processing record 3 of Set 7 | bandundu
# Processing record 4 of Set 7 | alakurtti
# Processing record 5 of Set 7 | burica
# City not found, skipping.
# Processing record 5 of Set 7 | mhlume
# Processing record 6 of Set 7 | kolda
# Processing record 7 of Set 7 | boende
# Processing record 8 of Set 7 | cidreira
# Processing record 9 of Set 7 | louisbourg
# City not found, skipping.
# Processing record 9 of Set 7 | hapur
# Processing record 10 of Set 7 | nueve de julio
# Processing record 11 of Set 7 | oriximina
# Processing record 12 of Set 7 | chuy
# Processing record 13 of Set 7 | sioux lookout
# Processing record 14 of Set 7 | uwayl
# City not found, skipping.
# Processing record 14 of Set 7 | chase
# Processing record 15 of Set 7 | lyngdal
# Processing record 16 of Set 7 | faya
# Processing record 17 of Set 7 | sistranda
# Processing record 18 of Set 7 | salalah
# Processing record 19 of Set 7 | maloy
# Processing record 20 of Set 7 | ponta do sol
# Processing record 21 of Set 7 | berlevag
# Processing record 22 of Set 7 | gold coast
# Processing record 23 of Set 7 | christchurch
# Processing record 24 of Set 7 | enshi
# Processing record 25 of Set 7 | komsomolskiy
# Processing record 26 of Set 7 | yeletskiy
# City not found, skipping.
# Processing record 26 of Set 7 | sassandra
# Processing record 27 of Set 7 | ust-omchug
# Processing record 28 of Set 7 | juneau
# Processing record 29 of Set 7 | omsukchan
# Processing record 30 of Set 7 | klaksvik
# Processing record 31 of Set 7 | zhigansk
# Processing record 32 of Set 7 | mehamn
# Processing record 33 of Set 7 | isangel
# Processing record 34 of Set 7 | turayf
# Processing record 35 of Set 7 | puerto colombia
# Processing record 36 of Set 7 | half moon bay
# Processing record 37 of Set 7 | san isidro
# Processing record 38 of Set 7 | sobolevo
# Processing record 39 of Set 7 | launceston
# Processing record 40 of Set 7 | kanata
# Processing record 41 of Set 7 | bhatkal
# Processing record 42 of Set 7 | aitape
# Processing record 43 of Set 7 | ambilobe
# Processing record 44 of Set 7 | kuala krai
# City not found, skipping.
# Processing record 44 of Set 7 | suntar
# Processing record 45 of Set 7 | chillan
# Processing record 46 of Set 7 | havre-saint-pierre
# Processing record 47 of Set 7 | clyde river
# Processing record 48 of Set 7 | broome
# Processing record 49 of Set 7 | majene
# Processing record 50 of Set 7 | daxian
# City not found, skipping.
# Processing record 50 of Set 7 | great falls
# Processing record 1 of Set 8 | port hardy
# Processing record 2 of Set 8 | fougamou
# Processing record 3 of Set 8 | stromness
# Processing record 4 of Set 8 | marawi
# Processing record 5 of Set 8 | bardiyah
# Processing record 6 of Set 8 | punta cardon
# Processing record 7 of Set 8 | lubao
# Processing record 8 of Set 8 | lorengau
# Processing record 9 of Set 8 | billings
# Processing record 10 of Set 8 | amstetten
# Processing record 11 of Set 8 | rayagada
# Processing record 12 of Set 8 | kasongo
# Processing record 13 of Set 8 | chiredzi
# Processing record 14 of Set 8 | vaitupu
# City not found, skipping.
# Processing record 14 of Set 8 | pacific grove
# Processing record 15 of Set 8 | narsaq
# Processing record 16 of Set 8 | vinstra
# Processing record 17 of Set 8 | espinho
# Processing record 18 of Set 8 | paita
# Processing record 19 of Set 8 | sorvag
# City not found, skipping.
# Processing record 19 of Set 8 | chapais
# Processing record 20 of Set 8 | buraydah
# Processing record 21 of Set 8 | providencia
# Processing record 22 of Set 8 | vysokogornyy
# Processing record 23 of Set 8 | waipawa
# Processing record 24 of Set 8 | alamosa
# Processing record 25 of Set 8 | vostok
# Processing record 26 of Set 8 | contamana
# Processing record 27 of Set 8 | springdale
# Processing record 28 of Set 8 | kupang
# Processing record 29 of Set 8 | katangli
# Processing record 30 of Set 8 | padang
# Processing record 31 of Set 8 | japura
# Processing record 32 of Set 8 | vardo
# Processing record 33 of Set 8 | puerto leguizamo
# Processing record 34 of Set 8 | kahului
# Processing record 35 of Set 8 | kiria
# Processing record 36 of Set 8 | guozhen
# Processing record 37 of Set 8 | paamiut
# Processing record 38 of Set 8 | koumac
# Processing record 39 of Set 8 | warah
# Processing record 40 of Set 8 | bihariganj
# Processing record 41 of Set 8 | ipoh
# Processing record 42 of Set 8 | mayo
# Processing record 43 of Set 8 | el wasta
# City not found, skipping.
# Processing record 43 of Set 8 | mikuni
# Processing record 44 of Set 8 | taltal
# Processing record 45 of Set 8 | jabinyanah
# Processing record 46 of Set 8 | anchorage
# Processing record 47 of Set 8 | plettenberg bay
# Processing record 48 of Set 8 | porto novo
# Processing record 49 of Set 8 | itaituba
# Processing record 50 of Set 8 | puerto escondido
# Processing record 1 of Set 9 | nagato
# Processing record 2 of Set 9 | pangnirtung
# Processing record 3 of Set 9 | la roda
# Processing record 4 of Set 9 | nanfeng
# Processing record 5 of Set 9 | sai buri
# Processing record 6 of Set 9 | bodhan
# Processing record 7 of Set 9 | prado
# Processing record 8 of Set 9 | camapua
# Processing record 9 of Set 9 | loding
# Processing record 10 of Set 9 | dekar
# Processing record 11 of Set 9 | chernyshevskiy
# Processing record 12 of Set 9 | henties bay
# Processing record 13 of Set 9 | khasan
# Processing record 14 of Set 9 | arkhara
# Processing record 15 of Set 9 | maneadero
# Processing record 16 of Set 9 | vila velha
# Processing record 17 of Set 9 | coulihaut
# City not found, skipping.
# Processing record 17 of Set 9 | cairns
# Processing record 18 of Set 9 | amapa
# Processing record 19 of Set 9 | sartell
# Processing record 20 of Set 9 | geraldton
# Processing record 21 of Set 9 | cockburn town
# Processing record 22 of Set 9 | canora
# Processing record 23 of Set 9 | katsuura
# Processing record 24 of Set 9 | spencer
# Processing record 25 of Set 9 | cayenne
# Processing record 26 of Set 9 | ostrovnoy
# Processing record 27 of Set 9 | karratha
# Processing record 28 of Set 9 | princeton
# Processing record 29 of Set 9 | nnewi
# Processing record 30 of Set 9 | progreso
# Processing record 31 of Set 9 | altamira
# Processing record 32 of Set 9 | camacha
# Processing record 33 of Set 9 | san andres
# Processing record 34 of Set 9 | grand-santi
# Processing record 35 of Set 9 | mount isa
# Processing record 36 of Set 9 | los llanos de aridane
# Processing record 37 of Set 9 | nipawin
# Processing record 38 of Set 9 | novyy urgal
# Processing record 39 of Set 9 | balezino
# Processing record 40 of Set 9 | letterkenny
# Processing record 41 of Set 9 | tiznit
# Processing record 42 of Set 9 | manono
# Processing record 43 of Set 9 | alugan
# Processing record 44 of Set 9 | urdzhar
# City not found, skipping.
# Processing record 44 of Set 9 | scarborough
# Processing record 45 of Set 9 | constitucion
# Processing record 46 of Set 9 | ixtapa
# Processing record 47 of Set 9 | maghama
# City not found, skipping.
# Processing record 47 of Set 9 | marystown
# Processing record 48 of Set 9 | miranorte
# City not found, skipping.
# Processing record 48 of Set 9 | conceicao do araguaia
# Processing record 49 of Set 9 | sorland
# Processing record 50 of Set 9 | pingdingshan
# Processing record 1 of Set 10 | george town
# Processing record 2 of Set 10 | kachug
# Processing record 3 of Set 10 | taoudenni
# Processing record 4 of Set 10 | beyneu
# Processing record 5 of Set 10 | batouri
# Processing record 6 of Set 10 | vestmanna
# Processing record 7 of Set 10 | karauzyak
# City not found, skipping.
# Processing record 7 of Set 10 | manaure
# Processing record 8 of Set 10 | laguna
# Processing record 9 of Set 10 | yen bai
# Processing record 10 of Set 10 | sherlovaya gora
# Processing record 11 of Set 10 | bastia
# Processing record 12 of Set 10 | yining
# Processing record 13 of Set 10 | englehart
# Processing record 14 of Set 10 | coruripe
# Processing record 15 of Set 10 | ahuimanu
# Processing record 16 of Set 10 | palmer
# Processing record 17 of Set 10 | longlac
# City not found, skipping.
# Processing record 17 of Set 10 | portland
# Processing record 18 of Set 10 | khorixas
# Processing record 19 of Set 10 | monywa
# Processing record 20 of Set 10 | gimbi
# Processing record 21 of Set 10 | sabang
# Processing record 22 of Set 10 | camana
# Processing record 23 of Set 10 | brae
# Processing record 24 of Set 10 | te anau
# Processing record 25 of Set 10 | sibu
# Processing record 26 of Set 10 | coquimbo
# Processing record 27 of Set 10 | ambovombe
# Processing record 28 of Set 10 | tazovskiy
# Processing record 29 of Set 10 | vilhena
# Processing record 30 of Set 10 | mahenge
# Processing record 31 of Set 10 | tagusao
# Processing record 32 of Set 10 | alotau
# City not found, skipping.
# Processing record 32 of Set 10 | baguanos
# Processing record 33 of Set 10 | yatou
# Processing record 34 of Set 10 | nalvo
# Processing record 35 of Set 10 | xiongshi
# City not found, skipping.
# Processing record 35 of Set 10 | nanortalik
# Processing record 36 of Set 10 | mastung
# Processing record 37 of Set 10 | riverton
# Processing record 38 of Set 10 | batagay-alyta
# Processing record 39 of Set 10 | ploemeur
# Processing record 40 of Set 10 | vallenar
# Processing record 41 of Set 10 | parabel
# Processing record 42 of Set 10 | eyl
# Processing record 43 of Set 10 | chake chake
# Processing record 44 of Set 10 | point pedro
# Processing record 45 of Set 10 | klamath falls
# Processing record 46 of Set 10 | krasnaya gora
# Processing record 47 of Set 10 | ndele
# Processing record 48 of Set 10 | gondanglegi
# Processing record 49 of Set 10 | belmonte
# Processing record 50 of Set 10 | khartoum
# Processing record 1 of Set 11 | tezu
# Processing record 2 of Set 11 | goulburn
# Processing record 3 of Set 11 | karamea
# City not found, skipping.
# Processing record 3 of Set 11 | necochea
# Processing record 4 of Set 11 | gwadar
# Processing record 5 of Set 11 | aras
# Processing record 6 of Set 11 | keetmanshoop
# Processing record 7 of Set 11 | gilbues
# Processing record 8 of Set 11 | ortigueira
# Processing record 9 of Set 11 | karaul
# City not found, skipping.
# Processing record 9 of Set 11 | felipe carrillo puerto
# Processing record 10 of Set 11 | mednogorsk
# Processing record 11 of Set 11 | hammerfest
# Processing record 12 of Set 11 | sitka
# Processing record 13 of Set 11 | port augusta
# Processing record 14 of Set 11 | kushiro
# Processing record 15 of Set 11 | santa cruz de tenerife
# Processing record 16 of Set 11 | chelbasskaya
# Processing record 17 of Set 11 | viligili
# City not found, skipping.
# Processing record 17 of Set 11 | kilindoni
# Processing record 18 of Set 11 | ahipara
# Processing record 19 of Set 11 | imeni poliny osipenko
# Processing record 20 of Set 11 | morehead
# Processing record 21 of Set 11 | katima mulilo
# Processing record 22 of Set 11 | udaipur
# Processing record 23 of Set 11 | munster
# Processing record 24 of Set 11 | meyungs
# City not found, skipping.
# Processing record 24 of Set 11 | usinsk
# Processing record 25 of Set 11 | baracoa
# Processing record 26 of Set 11 | nangomba
# Processing record 27 of Set 11 | port hawkesbury
# Processing record 28 of Set 11 | raudeberg
# Processing record 29 of Set 11 | barcelona
# Processing record 30 of Set 11 | qasigiannguit
# Processing record 31 of Set 11 | jiroft
# City not found, skipping.
# Processing record 31 of Set 11 | cave spring
# Processing record 32 of Set 11 | ontario
# Processing record 33 of Set 11 | copiapo
# Processing record 34 of Set 11 | mayumba
# Processing record 35 of Set 11 | rawah
# Processing record 36 of Set 11 | arona
# Processing record 37 of Set 11 | wuda
# Processing record 38 of Set 11 | lasa
# Processing record 39 of Set 11 | altay
# Processing record 40 of Set 11 | formosa
# Processing record 41 of Set 11 | chaozhou
# Processing record 42 of Set 11 | jiujiang
# Processing record 43 of Set 11 | thunder bay
# Processing record 44 of Set 11 | constantine
# Processing record 45 of Set 11 | neiafu
# Processing record 46 of Set 11 | jabiru
# City not found, skipping.

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dataframe for all the cities scanned above and populate the values for each column using a dictionary
CityDataPoints = pd.DataFrame({"City": citys,
            "Latitude": lats,
            "Longitude": longs,
            "Max Temperature": temperatures,
            "Humidity": humiditylevels,
            "Cloudiness": cloudiness,
            "Wind Speed": windspeed,
            "Country": countries,
            "Date": dates})
# When rerunning the code, I noticed it was generating an additional column at the beginning when I did to_csv
# as instructed in the Slack channel. But at first I thought it was happening here, so I tried to pop the column
# but the column didn't exist until I did to_csv I eventually learned, then used index = False to not bring it. 
# CityDataPoints.pop("Unnamed: 0")
CityDataPoints.head()
# Out:
#                 City  Latitude  Longitude  Max Temperature  Humidity  \
# 0      Pervomayskaya   43.4033    45.5261            69.60        78
# 1          Busselton  -33.6500   115.3333            56.14        70
# 2            Lugovoy   42.9472    72.7644            67.53        50
# 3        Provideniya   64.3833  -173.3000            53.53        65
# 4  Saint Paul Harbor   57.7900  -152.4072            62.11        72
#
#    Cloudiness  Wind Speed Country        Date
# 0           0        2.24      RU  1659230262
# 1          79       10.58      AU  1659230263
# 2           8        5.10      KZ  1659230263
# 3          98        6.31      RU  1659230263
# 4         100        9.22      US  1659230264

# %%
# Save the data to a csv file and then comment out the code above to keep the data static and support reruns. 
CityDataPoints.to_csv("weatherdata.csv",index=False)

# %%
# Read the csv file as a DF.

CityDataPointsDF = pd.read_csv("weatherdata.csv")
CityDataPointsDF.head()
# Out:
#                 City  Latitude  Longitude  Max Temperature  Humidity  \
# 0      Pervomayskaya   43.4033    45.5261            69.60        78
# 1          Busselton  -33.6500   115.3333            56.14        70
# 2            Lugovoy   42.9472    72.7644            67.53        50
# 3        Provideniya   64.3833  -173.3000            53.53        65
# 4  Saint Paul Harbor   57.7900  -152.4072            62.11        72
#
#    Cloudiness  Wind Speed Country        Date
# 0           0        2.24      RU  1659230262
# 1          79       10.58      AU  1659230263
# 2           8        5.10      KZ  1659230263
# 3          98        6.31      RU  1659230263
# 4         100        9.22      US  1659230264

# %%
CityDataPointsDF.describe()
# Out:
#          Latitude   Longitude  Max Temperature    Humidity  Cloudiness  \
# count  545.000000  545.000000       545.000000  545.000000  545.000000
# mean    18.476792   15.058560        68.955376   73.077064   54.737615
# std     33.828173   92.139717        13.536851   18.083993   41.015005
# min    -54.800000 -179.166700        34.410000    1.000000    0.000000
# 25%     -8.619900  -68.300000        57.510000   64.000000    9.000000
# 50%     21.444700   16.588700        71.620000   76.000000   68.000000
# 75%     46.616600  101.082900        79.050000   86.000000  100.000000
# max     78.218600  178.416700       102.560000  100.000000  100.000000
#
#        Wind Speed          Date
# count  545.000000  5.450000e+02
# mean     7.868716  1.659231e+09
# std      5.664760  2.414687e+02
# min      0.000000  1.659230e+09
# 25%      3.560000  1.659230e+09
# 50%      6.350000  1.659231e+09
# 75%     11.180000  1.659231e+09
# max     28.390000  1.659231e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Max humidity above is 100.00%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  550.000000  550.000000  550.000000  550.000000  550.000000  550.000000
# mean    19.973545   17.124400   58.331400   67.890909   52.141818    8.544800
# std     33.284840   91.595451   25.795297   20.864881   35.766469    6.078869
# min    -54.800000 -179.170000  -11.340000    9.000000    0.000000    0.160000
# 25%     -8.077500  -64.627500   42.800000   55.000000   20.000000    4.525000
# 50%     23.630000   19.635000   64.940000   72.000000   57.000000    7.325000
# 75%     48.672500   97.350000   78.800000   83.000000   86.750000   11.410000
# max     78.220000  179.320000  102.200000  100.000000  100.000000   46.080000
#
#                Date
# count  5.500000e+02
# mean   1.585764e+09
# std    5.539674e+01
# min    1.585764e+09
# 25%    1.585764e+09
# 50%    1.585764e+09
# 75%    1.585764e+09
# max    1.585764e+09

# %%
#  Get the indices of cities that have humidity over 100%.
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create a scatter plot to track latitude vs max temperature. Set the size, add a grid, and save a copy. 

plt.scatter(CityDataPointsDF['Latitude'],CityDataPointsDF['Max Temperature'],alpha=0.75,edgecolors='black')
plt.xlabel('Latitude') 
plt.ylabel('Temperature (F)')
plt.title(f"City Latitude vs. Max Temperature ({time.strftime('%m/%d/%y')})")
plt.xlim(min(CityDataPointsDF['Latitude'])-10,max(CityDataPointsDF['Latitude'])+10)
plt.ylim(min(CityDataPointsDF['Max Temperature'])-10,max(CityDataPointsDF['Max Temperature'])+10)
plt.grid()
plt.savefig("Pictures/LatitudeVsMaxtemp.png")

# The code is analyzing the relationship between latitude and max temperature using a scatter plot.
# 0 latitude is the equator so it makes sense that as latitude approaches zero from both directions maximum temperatures rise.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create a scatter plot to track latitude vs Humidity. Set the size, add a grid, and save a copy. 

plt.scatter(CityDataPointsDF['Latitude'],CityDataPointsDF['Humidity'],alpha=0.75,edgecolors='black')
plt.xlabel('Latitude') 
plt.ylabel('Humidity')
plt.title(f"City Latitude vs. Humidity ({time.strftime('%m/%d/%y')})")
plt.xlim(min(CityDataPointsDF['Latitude'])-10,max(CityDataPointsDF['Latitude'])+10)
plt.ylim(min(CityDataPointsDF['Humidity'])-10,max(CityDataPointsDF['Humidity'])+10)
plt.grid()
plt.savefig("Pictures/LatitudeVsHumidity.png")

# The code is analyzing the relationship between latitude and Humidity using a scatter plot.
# High humidity seems to be the norm, but as you gain distance from the equator there grow pockets of low humidity.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create a scatter plot to track latitude vs Cloudiness. Set the size, add a grid, and save a copy. 

plt.scatter(CityDataPointsDF['Latitude'],CityDataPointsDF['Cloudiness'],alpha=0.75,edgecolors='black')
plt.xlabel('Latitude') 
plt.ylabel('Cloudiness')
plt.title(f"City Latitude vs. Cloudiness ({time.strftime('%m/%d/%y')})")
plt.xlim(min(CityDataPointsDF['Latitude'])-10,max(CityDataPointsDF['Latitude'])+10)
plt.ylim(min(CityDataPointsDF['Cloudiness'])-10,max(CityDataPointsDF['Cloudiness'])+10)
plt.grid()
plt.savefig("Pictures/LatitudeVsCloudiness.png")

# The code is analyzing the relationship between latitude and Cloudiness using a scatter plot.
# There doesn't seem to be as much of a relationship here as there was in previous graphs. The data is evenly spread out.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create a scatter plot to track latitude vs Wind Speed. Set the size, add a grid, and save a copy. 

plt.scatter(CityDataPointsDF['Latitude'],CityDataPointsDF['Wind Speed'],alpha=0.75,edgecolors='black')
plt.xlabel('Latitude') 
plt.ylabel('Wind Speed')
plt.title(f"City Latitude vs. Wind Speed ({time.strftime('%m/%d/%y')})")
plt.xlim(min(CityDataPointsDF['Latitude'])-10,max(CityDataPointsDF['Latitude'])+10)
plt.ylim(min(CityDataPointsDF['Wind Speed'])-10,max(CityDataPointsDF['Wind Speed'])+10)
plt.grid()
plt.savefig("Pictures/LatitudeVsWindSpeed.png")

# The code is analyzing the relationship between latitude and Cloudiness using a scatter plot.
# Again, not a strong relationship to my eye. Near and south of the equator wind speed seems to be stronger.

# %% [markdown]
# ## Linear Regression

# %%
# Separate my data frame into one for the Northern Hempisphere and one for Southern.

NorthHemDF = CityDataPointsDF.loc[CityDataPointsDF["Latitude"] >= 0]
SouthHemDF = CityDataPointsDF.loc[CityDataPointsDF["Latitude"] < 0]
# NorthHemDF.head()

# Since all values are measured against latitudes and I have to set X and Y values for lingress, declaring them here.
NorthY_Values = NorthHemDF["Latitude"]
SouthY_Values = SouthHemDF["Latitude"]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Now we are recreating the plots separated by hemisphere and adding linear regression data on top to show correlation.
# Set X Values, do the linear regression formula, Create the line of best fit, then place all of it onto a scatter plot.
X_Values = NorthHemDF["Max Temperature"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(X_Values, NorthY_Values)
regress_values = X_Values * slope + intercept
RSlope = round(slope,2)
RIntercept = round(intercept,2)
LineOfBestFit = f"y = {RSlope}x + {RIntercept}" 
RValueText = f"The r-value is: {rvalue**2}."
plt.scatter(X_Values,NorthY_Values)
# Adds the line to the graph, colors it red. Then adds the text to the plot. 
plt.plot(X_Values,regress_values,"r-")
plt.annotate(LineOfBestFit, xy = (80,75), color = "red")
plt.title("Maximum Temperature vs. Latitude in the Northern Hemisphere")
plt.xlabel("Maximum Temperatures")
plt.ylabel("Latitudes")
plt.show()
print(RValueText)

# As latitude increases, maximum temperature decreases. This makes sense as New York is colder than Atlanta.
# Out:
# The r-value is: 0.41752647304788465.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Set X Values, do the linear regression formula, Create the line of best fit, then place all of it onto a scatter plot.
X_Values = SouthHemDF["Max Temperature"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(X_Values, SouthY_Values)
regress_values = X_Values * slope + intercept
RSlope = round(slope,2)
RIntercept = round(intercept,2)
LineOfBestFit = f"y = {RSlope}x + {RIntercept}" 
RValueText = f"The r-value is: {rvalue**2}."
plt.scatter(X_Values,SouthY_Values)
# Adds the line to the graph, colors it red. Then adds the text to the plot. 
plt.plot(X_Values,regress_values,"r-")
plt.annotate(LineOfBestFit, xy = (60,-50), color = "red")
plt.title("Maximum Temperature vs. Latitude in the Southern Hemisphere")
plt.xlabel("Maximum Temperatures")
plt.ylabel("Latitudes")
plt.show()
print(RValueText)

# These plots are just the first one from this notebook broken down in two since the equator is the point that
# reversal in the data. They show that as you approach the equator, maximum temperatures rise on average. Strong relationship.
# Out:
# The r-value is: 0.6584332182419259.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Set X Values, do the linear regression formula, Create the line of best fit, then place all of it onto a scatter plot.
X_Values = NorthHemDF["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(X_Values, NorthY_Values)
regress_values = X_Values * slope + intercept
RSlope = round(slope,2)
RIntercept = round(intercept,2)
LineOfBestFit = f"y = {RSlope}x + {RIntercept}" 
RValueText = f"The r-value is: {rvalue**2}."
plt.scatter(X_Values,NorthY_Values)
# Adds the line to the graph, colors it red. Then adds the text to the plot. 
plt.plot(X_Values,regress_values,"r-")
plt.annotate(LineOfBestFit, xy = (80,75), color = "red")
plt.title("Humidity vs. Latitude in the Northern Hemisphere")
plt.xlabel("Humidity")
plt.ylabel("Latitudes")
plt.show()
print(RValueText)

# There is really weak negative correlation here. Hard to say the variables are related.
# Out:
# The r-value is: 0.005712016711491901.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Set X Values, do the linear regression formula, Create the line of best fit, then place all of it onto a scatter plot.
X_Values = SouthHemDF["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(X_Values, SouthY_Values)
regress_values = X_Values * slope + intercept
RSlope = round(slope,2)
RIntercept = round(intercept,2)
LineOfBestFit = f"y = {RSlope}x + {RIntercept}" 
RValueText = f"The r-value is: {rvalue**2}."
plt.scatter(X_Values,SouthY_Values)
# Adds the line to the graph, colors it red. Then adds the text to the plot. 
plt.plot(X_Values,regress_values,"r-")
plt.annotate(LineOfBestFit, xy = (20,-50), color = "red")
plt.title("Humidity vs. Latitude in the Southern Hemisphere")
plt.xlabel("Humidity")
plt.ylabel("Latitudes")
plt.show()
print(RValueText)

# Similarly weak correlation but this time it's positive, which makes sense. These graphs imply there isn't much
# of a relationship between humidity and latitudes.
# Out:
# The r-value is: 0.003558829312063225.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Set X Values, do the linear regression formula, Create the line of best fit, then place all of it onto a scatter plot.
X_Values = NorthHemDF["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(X_Values, NorthY_Values)
regress_values = X_Values * slope + intercept
RSlope = round(slope,2)
RIntercept = round(intercept,2)
LineOfBestFit = f"y = {RSlope}x + {RIntercept}" 
RValueText = f"The r-value is: {rvalue**2}."
plt.scatter(X_Values,NorthY_Values)
# Adds the line to the graph, colors it red. Then adds the text to the plot. 
plt.plot(X_Values,regress_values,"r-")
plt.annotate(LineOfBestFit, xy = (30,75), color = "red")
plt.title("Cloudiness vs. Latitude in the Northern Hemisphere")
plt.xlabel("Cloudiness")
plt.ylabel("Latitudes")
plt.show()
print(RValueText)

# There is even weaker correlation between latitude and levels of cloudiness than with the other variables.
# Out:
# The r-value is: 0.0011703680207478333.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Set X Values, do the linear regression formula, Create the line of best fit, then place all of it onto a scatter plot.
X_Values = SouthHemDF["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(X_Values, SouthY_Values)
regress_values = X_Values * slope + intercept
RSlope = round(slope,2)
RIntercept = round(intercept,2)
LineOfBestFit = f"y = {RSlope}x + {RIntercept}" 
RValueText = f"The r-value is: {rvalue**2}."
plt.scatter(X_Values,SouthY_Values)
# Adds the line to the graph, colors it red. Then adds the text to the plot. 
plt.plot(X_Values,regress_values,"r-")
plt.annotate(LineOfBestFit, xy = (60,-50), color = "red")
plt.title("Cloudiness vs. Latitude in the Southern Hemisphere")
plt.xlabel("Cloudiness")
plt.ylabel("Latitudes")
plt.show()
print(RValueText)

# These slopes and R values are showing that there is almost zero relationship between degrees of cloudiness and latitudes.
# Out:
# The r-value is: 0.0015621064618691338.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Set X Values, do the linear regression formula, Create the line of best fit, then place all of it onto a scatter plot.
X_Values = NorthHemDF["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(X_Values, NorthY_Values)
regress_values = X_Values * slope + intercept
RSlope = round(slope,2)
RIntercept = round(intercept,2)
LineOfBestFit = f"y = {RSlope}x + {RIntercept}" 
RValueText = f"The r-value is: {rvalue**2}."
plt.scatter(X_Values,NorthY_Values)
# Adds the line to the graph, colors it red. Then adds the text to the plot. 
plt.plot(X_Values,regress_values,"r-")
plt.annotate(LineOfBestFit, xy = (20,75), color = "red")
plt.title("Wind Speed (MPH) vs. Latitude in the Northern Hemisphere")
plt.xlabel("Wind Speed (MPH)")
plt.ylabel("Latitudes")
plt.show()
print(RValueText)
# Out:
# The r-value is: 6.7116427129980515e-06.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Set X Values, do the linear regression formula, Create the line of best fit, then place all of it onto a scatter plot.
X_Values = SouthHemDF["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(X_Values, SouthY_Values)
regress_values = X_Values * slope + intercept
RSlope = round(slope,2)
RIntercept = round(intercept,2)
LineOfBestFit = f"y = {RSlope}x + {RIntercept}" 
RValueText = f"The r-value is: {rvalue**2}."
plt.scatter(X_Values,SouthY_Values)
# Adds the line to the graph, colors it red. Then adds the text to the plot. 
plt.plot(X_Values,regress_values,"r-")
plt.annotate(LineOfBestFit, xy = (18,-2), color = "red")
plt.title("Wind Speed (MPH) vs. Latitude in the Southern Hemisphere")
plt.xlabel("Wind Speed (MPH)")
plt.ylabel("Latitudes")
plt.show()
print(RValueText)

# Interestingly, there is close to zero correlation in wind speed vs latitudes in the norhtern hemisphere, but there is 
# minor negative correlation between the two variables in the southern hemisphere.
# Out:
# The r-value is: 0.062093874851595864.
